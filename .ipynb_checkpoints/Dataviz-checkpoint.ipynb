# %% [markdown]
# # La visualisation des données

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Graphe 1

# %%
# Configuration de Seaborn pour une meilleure apparence with '.set'
sns.set(style="whitegrid", font_scale=1)

# Créer les données pour la droite d'équation x = 3y
y_values = np.linspace(0, 50/3, 100) #100 valeurs équidistances allant de 0 à '50/3'
x_values = 3 * y_values

# Création de la figure et d'un axe ('ax1')
fig, ax1 = plt.subplots()

# Tracer la droite
ax1.plot(x_values, y_values, color='red', label='x = 3y')

# Définition des libellés
ax1.set_xlabel('Axe des x')
ax1.set_ylabel('Axe des y')
ax1.set_title('Graphe 1')

# Ajoute la légende
ax1.legend()

# Afficher le graphique
plt.show()

# %% [markdown]
# ### Graphe 2

# %%
sales_df = pd.read_csv("company_sales_data.csv")
display(sales_df)
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %% [markdown]
# #### Un graphe qui donne la courbe du profit total réalisé chaque mois

# %%
# Supposons que vous ayez un dictionnaire de correspondance des numéros de mois aux noms de mois
mois_dict = {
    1: 'Jan.',
    2: 'Fév.',
    3: 'Mars',
    4: 'Avr.',
    5: 'Mai',
    6: 'Juin',
    7: 'Juil.',
    8: 'Août',
    9: 'Sept.',
    10: 'Oct.',
    11: 'Nov.',
    12: 'Déc.'
}

y_values = sales_df['total_profit']
x_values = list(range(1, 13))

fig, ax1 = plt.subplots()

ax1.plot(x_values, y_values, color='C4', marker='o', label='Profit total par mois')

# Remplacer les valeurs numériques de l'axe des abscisses par les noms des mois
ax1.set_xticks(x_values)  # Les positions des marqueurs sur l'axe des abscisses
ax1.set_xticklabels([mois_dict[num] for num in x_values], rotation=45, ha='right')  # Les noms des mois correspondants

ax1.set_xlabel('Mois')
ax1.set_ylabel('Profit total (en €)')
ax1.set_title('Graphe 2')

ax1.legend()

plt.show()

# %% [markdown]
# ### Graphe 3

# %% [markdown]
# #### Un graphe qui donne la courbe de profit pour chaque produit, en fonction du temps

# %%
x = list(range(1, 13))

fig, ax = plt.subplots()

ax.plot(x, sales_df.iloc[:, 1:7]*10, label=['Crème visage','Nettoyant visage','Dentifirce','Savon','Shampoing','Crème de corps'], linestyle='-', marker='.' )

#facewash and moisturizer are over each other

# To convert num in month name
ax.set_xticks(x)  
ax.set_xticklabels([mois_dict[num] for num in x], rotation=45, ha='right')

ax.set_xlabel('Mois')
ax.set_ylabel('Profit total (en €)')
ax.set_title('Graphe 3')

ax.legend(fontsize=7, ncol=2)
plt.show()

# %% [markdown]
# ### Graphe 4

# %% [markdown]
# #### Un graphe qui compare, chaque mois, le nombre d'unités vendus pour chaque produit. À vous de choisir la meilleure représentation pour connaître le produit le plus vendu par mois.

# %%
product_columns = ['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo', 'moisturizer']

# Création du graphique
plt.figure(figsize=(12, 6))  # Définir la taille du graphe

# Initialisation des positions des barres sur l'axe X
x_positions = range(len(sales_df['month_number']))

# Boucle sur chaque produit pour créer les barres empilées
bottom = [0] * len(sales_df['month_number'])  # Variable pour garder une trace de la hauteur de la barre précédente
for product in product_columns:
    plt.bar(
        x_positions,
        sales_df[product],
        bottom=bottom,
        label=product
    )
    bottom = [bottom[i] + sales_df[product][i] for i in range(len(sales_df['month_number']))]

# Configurations supplémentaires du graphe
plt.xlabel('Mois')
plt.ylabel('Nombre d\'unités vendues')
plt.title('Comparaison des ventes mensuelles par produit')
plt.legend(loc='upper left', ncol=2)
plt.xticks(x_positions, sales_df['month_number'])  # Utilise les mois sur l'axe X
plt.tight_layout()  # Pour éviter les chevauchements de texte

# Afficher le graphe
plt.show()

# %% [markdown]
# ### Graphe 5

# %% [markdown]
# #### Un graphe qui donne la contribution de chaque produit dans le profit total (sur l'année étudiée) en  pourcentage pour chaque produit.

# %%
ca = sales_df['total_profit'].sum()

def product_part(product):
    product = product.sum()*10/ca*100
    product_round = product.round(0).astype(int)
    return product_round

columns_to_calculate = ['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo', 'moisturizer']

# Calcul des parties pour chaque colonne à l'aide d'une boucle
results = {}
for column in columns_to_calculate:
    results[column] = product_part(sales_df[column])

# Récupérer les noms des colonnes et les valeurs calculées à partir de results.items()
labels, values = zip(*results.items())

# Créer le camembert
plt.figure(figsize=(8, 5))  # Changer la taille du graphique si nécessaire
plt.pie(values, labels=labels, autopct='%1i%%', startangle=140)
plt.title('Part de chaque produit dans le CA total')
plt.axis('equal')  # Assurer un affichage circulaire
plt.show()

# %% [markdown]
# ### Graphe 6

# %% [markdown]
# #### Un graphe pie chart qui donne la répartition des produits par catégorie, avec le pourcentage par produit (nb de produits de telle catégorie / nb de produits totaux).

# %%
customers_df = pd.read_csv("../datas/dataset_bookstore_dataviz/customers.csv")
display(customers_df)
# Out:
#      client_id sex  birth
# 0       c_4410   f   1967
# 1       c_7839   f   1975
# 2       c_1699   f   1984
# 3       c_5961   f   1962
# 4       c_5320   m   1943
# ...        ...  ..    ...
# 8618    c_7920   m   1956
# 8619    c_7403   f   1970
# 8620    c_5119   m   1974
# 8621    c_5643   f   1968
# 8622      c_84   f   1982
#
# [8623 rows x 3 columns]

# %%
products_df = pd.read_csv("../datas/dataset_bookstore_dataviz/products.csv")
display(products_df)
# Out:
#      id_prod   price  categ
# 0     0_1421   19.99      0
# 1     0_1368    5.13      0
# 2      0_731   17.99      0
# 3      1_587    4.99      1
# 4     0_1507    3.99      0
# ...      ...     ...    ...
# 3281    2_23  115.99      2
# 3282   0_146   17.14      0
# 3283   0_802   11.22      0
# 3284   1_140   38.56      1
# 3285  0_1920   25.16      0
#
# [3286 rows x 3 columns]

# %%
transactions_df = pd.read_csv("../datas/dataset_bookstore_dataviz/transactions.csv")
display(transactions_df)
# Out:
#        id_prod                        date session_id client_id
# 0       0_1483  2021-04-10 18:37:28.723910    s_18746    c_4450
# 1        2_226  2022-02-03 01:55:53.276402   s_159142     c_277
# 2        1_374  2021-09-23 15:13:46.938559    s_94290    c_4270
# 3       0_2186  2021-10-17 03:27:18.783634   s_105936    c_4597
# 4       0_1351  2021-07-17 20:34:25.800563    s_63642    c_1242
# ...        ...                         ...        ...       ...
# 336811   1_671  2021-05-28 12:35:46.214839    s_40720    c_3454
# 336812   0_759  2021-06-19 00:19:23.917703    s_50568    c_6268
# 336813  0_1256  2021-03-16 17:31:59.442007     s_7219    c_4137
# 336814   2_227  2021-10-30 16:50:15.997750   s_112349       c_5
# 336815  0_1417  2021-06-26 14:38:19.732946    s_54117    c_6714
#
# [336816 rows x 4 columns]

# %%
display(products_df)
# Out:
#      id_prod   price  categ
# 0     0_1421   19.99      0
# 1     0_1368    5.13      0
# 2      0_731   17.99      0
# 3      1_587    4.99      1
# 4     0_1507    3.99      0
# ...      ...     ...    ...
# 3281    2_23  115.99      2
# 3282   0_146   17.14      0
# 3283   0_802   11.22      0
# 3284   1_140   38.56      1
# 3285  0_1920   25.16      0
#
# [3286 rows x 3 columns]
